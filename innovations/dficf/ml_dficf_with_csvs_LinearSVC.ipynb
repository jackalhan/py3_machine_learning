# %%
import pandas as pd
import numpy as np
import os
import json
import csv
from sklearn import preprocessing
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

# %%
path = "/home/jackalhan/Development/app_data/tf_idf_hiarchical"
dficf_path = os.path.join(path, 'dficf')
tfidf_path = os.path.join(path, 'tfidf')

# %%
## pandas style
# dficf_train_df = pd.read_csv(os.path.join(dficf_path, 'dficf_train_all_in_one.csv'), skipinitialspace=True, 
#                              converters={'vector':lambda x: json.loads(x)})
# dficf_test_df = pd.read_csv(os.path.join(dficf_path, 'dficf_test_all_in_one.csv'))

# tfidf_train_df = pd.read_csv(os.path.join(tfidf_path, 'tfidf_train_all_in_one.csv'))
# tfidf_test_df = pd.read_csv(os.path.join(tfidf_path, 'tfidf_test_all_in_one.csv'))

# %%
#DFICF Train
with open(os.path.join(dficf_path, 'dficf_train_all_in_one.csv'), 'r') as f:
    reader = csv.reader(f, skipinitialspace=True)
    header = next(reader)
    _X_train = []
    _y_train = []
    for x in reader:
        _X_train.append(json.loads(x[1]))
        _y_train.append(x[2])
    df_X_train = np.array(_X_train)
    df_y_train = np.array(_y_train).reshape(len(_y_train),1)
    del _X_train
    del _y_train
    
#DFICF Test
with open(os.path.join(dficf_path, 'dficf_test_all_in_one.csv'), 'r') as f:
    reader = csv.reader(f, skipinitialspace=True)
    header = next(reader)
    # ------------------------------------------------
    # reader needs to be sorted by actual index value in order to group same documents 
    # ------------------------------------------------
    sorted_reader = sorted(reader, key=lambda row: int(row[4]))
    
    _X_test = []
    _y_test = []
    _potential_category_test = []
    _actual_index_test = []
    for x in sorted_reader:
        _X_test.append(json.loads(x[1]))
        _potential_category_test.append(x[3])
        _actual_index_test.append(int(x[4]))
        _y_test.append(x[5])
    
    df_X_test = np.array(_X_test)
    df_y_test = np.array(_y_test).reshape(len(_y_test),1)
    df_potential_category_test = np.array(_potential_category_test).reshape(len(_potential_category_test),1)
    df_actual_index_test = np.array(_actual_index_test).reshape(len(_actual_index_test),1)
    ## ----------------------------------------------------
    # Actual_index is going to be used to group them so that each index can be 
    # trained to get
    # the best result and compare it with the actual y_test
    ## ----------------------------------------------------
    del _X_test
    del _y_test
    del _potential_category_test
    del _actual_index_test
    
#TFIDF Train
with open(os.path.join(tfidf_path, 'tfidf_train_all_in_one.csv'), 'r') as f:
    reader = csv.reader(f, skipinitialspace=True)
    header = next(reader)
    _X_train = []
    _y_train = []
    for x in reader:
        _X_train.append(json.loads(x[1]))
        _y_train.append(x[2])
    tf_X_train = np.array(_X_train)
    tf_y_train = np.array(_y_train).reshape(len(_y_train),1)
    del _X_train
    del _y_train
        
#TFIDF Test
with open(os.path.join(tfidf_path, 'tfidf_test_all_in_one.csv'), 'r') as f:
    reader = csv.reader(f, skipinitialspace=True)
    header = next(reader)
    _X_test = []
    _y_test = []
    for x in reader:
        _X_test.append(json.loads(x[1]))
        _y_test.append(x[2])
    tf_X_test = np.array(_X_test)
    tf_y_test = np.array(_y_test).reshape(len(_y_test),1)
    del _X_test
    del _y_test

# %% [markdown]
# ## Preprocessing for TFIDF

# %%
# TFIDF
tf_y_unique_labels = np.unique(tf_y_train)
tf_le = preprocessing.LabelEncoder()
tf_le.fit(tf_y_unique_labels)
# Out:
# LabelEncoder()

# %%
tf_y_train_encoded = tf_le.transform(tf_y_train)
# Out:
# /home/jackalhan/Development/Projects/Github/py3_machine_learning/venv/lib/python3.5/site-packages/sklearn/preprocessing/label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
tf_y_test_encoded = tf_le.transform(tf_y_test)
# Out:
# /home/jackalhan/Development/Projects/Github/py3_machine_learning/venv/lib/python3.5/site-packages/sklearn/preprocessing/label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## Preprocessing for DFICF

# %%
# TFIDF
df_y_unique_labels = np.unique(df_y_train)
df_le = preprocessing.LabelEncoder()
df_le.fit(df_y_unique_labels)
# Out:
# LabelEncoder()

# %%
df_y_train_encoded = df_le.transform(df_y_train)
# Out:
# /home/jackalhan/Development/Projects/Github/py3_machine_learning/venv/lib/python3.5/site-packages/sklearn/preprocessing/label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df_y_test_encoded = df_le.transform(df_y_test)
# Out:
# /home/jackalhan/Development/Projects/Github/py3_machine_learning/venv/lib/python3.5/site-packages/sklearn/preprocessing/label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # K-NearestNeighbours Classifier

# %%
clf = CalibratedClassifierCV(base_estimator=LinearSVC(penalty='l2', dual=False), cv=5)

# %% [markdown]
# ## TFIDF K-NN Processing

# %%
clf.fit(tf_X_train, tf_y_train_encoded)
# Out:
# CalibratedClassifierCV(base_estimator=LinearSVC(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#             cv=5, method='sigmoid')

# %%
#KNN Labels
clf.classes_
# Out:
# array([0, 1, 2, 3, 4])

# %%
#KNN Encoded Labels
tf_y_unique_labels
# Out:
# array(['business', 'entertainment', 'politics', 'sport', 'tech'],
#       dtype='<U13')

# %%
correct_predictions = 0
wrong_predictions = 0
for indx, _ in enumerate(tf_X_test):
    tf_X_sample_record = _.reshape(1, _.shape[0])
    #sample_indx = 0
    #tf_X_sample = tf_X_test[sample_indx].reshape(1, tf_X_test[sample_indx].shape[0])
    predicted = clf.predict_proba(tf_X_sample_record)
    print('Actual:', tf_y_test[indx])
    print('Predicted:', predicted)
    predicted_index = np.argmax(predicted)
    print('Predicted Index:', tf_y_test[indx])
    
    if (tf_y_unique_labels[predicted_index] == tf_y_test[indx]):
        correct_predictions +=1
        print('Correct')
    else:
        wrong_predictions +=1
        #print(predicted)
# Out:
# Actual: ['tech']
# Predicted: [[ 0.07594541  0.01873647  0.02610924  0.04336398  0.8358449 ]]
# Predicted Index: ['tech']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.00359696  0.0049514   0.0062612   0.95323075  0.03195968]]
# Predicted Index: ['sport']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.12737835  0.00542857  0.79798629  0.00285849  0.0663483 ]]
# Predicted Index: ['politics']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.01049312  0.91907723  0.01152179  0.02148664  0.03742122]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.00501617  0.02536706  0.01531949  0.94063843  0.01365884]]
# Predicted Index: ['sport']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.02064326  0.01114416  0.94809488  0.00882092  0.01129678]]
# Predicted Index: ['politics']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.0896562   0.02802303  0.01766989  0.02625103  0.83839985]]
# Predicted Index: ['tech']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.01159516  0.32349764  0.01667276  0.00882974  0.6394047 ]]
# Predicted Index: ['tech']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.14248454  0.54221179  0.09864721  0.08034281  0.13631365]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['business']
# Predicted: [[ 0.88569036  0.02061227  0.05301892  0.01749932  0.02317913]]
# Predicted Index: ['business']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.01142707  0.00817599  0.94889328  0.02133065  0.01017302]]
# Predicted Index: ['politics']
# Correct
# Actual: ['business']
# Predicted: [[ 0.89924064  0.00898261  0.05800412  0.01010712  0.02366549]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.91930447  0.03776817  0.0168005   0.0162076   0.00991926]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.81171216  0.01341746  0.00926718  0.01508165  0.15052155]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.95617035  0.01036479  0.01406696  0.00886647  0.01053144]]
# Predicted Index: ['business']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.01633384  0.02088577  0.01428389  0.92342027  0.02507623]]
# Predicted Index: ['sport']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.03873806  0.06062056  0.03742054  0.85158619  0.01163464]]
# Predicted Index: ['sport']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.01143049  0.85853655  0.02270956  0.07102079  0.03630261]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.01439671  0.07411931  0.04168234  0.8600568   0.00974485]]
# Predicted Index: ['sport']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.01581582  0.02957017  0.01887955  0.9227608   0.01297367]]
# Predicted Index: ['sport']
# Correct
# Actual: ['business']
# Predicted: [[ 0.85987422  0.03026788  0.06302719  0.03166277  0.01516795]]
# Predicted Index: ['business']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.01314977  0.00700332  0.01819072  0.0064833   0.95517289]]
# Predicted Index: ['tech']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.00579347  0.02350492  0.01972521  0.92844904  0.02252736]]
# Predicted Index: ['sport']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.01392231  0.93275792  0.00664669  0.03807404  0.00859904]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.0294043   0.01427884  0.16552764  0.77524736  0.01554186]]
# Predicted Index: ['sport']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.00568415  0.0093034   0.96333827  0.01104231  0.01063186]]
# Predicted Index: ['politics']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.04119624  0.02050068  0.01231437  0.05201121  0.8739775 ]]
# Predicted Index: ['tech']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.04114238  0.8714665   0.03307871  0.03931701  0.0149954 ]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['business']
# Predicted: [[ 0.88516035  0.01919435  0.01352552  0.01881368  0.0633061 ]]
# Predicted Index: ['business']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.02077547  0.01986488  0.92081159  0.00832963  0.03021843]]
# Predicted Index: ['politics']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.06369695  0.85447117  0.02254202  0.04232286  0.016967  ]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.02091455  0.80437057  0.02584658  0.12323358  0.02563472]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.01768426  0.01623824  0.90820588  0.01551641  0.04235521]]
# Predicted Index: ['politics']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.02196962  0.01219351  0.95224066  0.0041271   0.0094691 ]]
# Predicted Index: ['politics']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.03173892  0.0189912   0.0325575   0.90243905  0.01427333]]
# Predicted Index: ['sport']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.05450987  0.0758103   0.03035364  0.01835289  0.8209733 ]]
# Predicted Index: ['tech']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.0315708   0.00674109  0.9430867   0.00464211  0.01395929]]
# Predicted Index: ['politics']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.01984683  0.0203021   0.02878272  0.88640154  0.04466681]]
# Predicted Index: ['sport']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.00255357  0.02610528  0.08710527  0.4176854   0.46655047]]
# Predicted Index: ['tech']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.02255243  0.14117538  0.79576633  0.02503877  0.01546709]]
# Predicted Index: ['politics']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.08844796  0.06246746  0.75830524  0.05001006  0.04076928]]
# Predicted Index: ['politics']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.00432041  0.93879802  0.01266732  0.03214919  0.01206506]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.02561464  0.00983563  0.06270736  0.00798083  0.89386153]]
# Predicted Index: ['tech']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.00593536  0.06081595  0.01417899  0.91323529  0.00583442]]
# Predicted Index: ['sport']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.01944015  0.01263801  0.05437505  0.89489566  0.01865113]]
# Predicted Index: ['sport']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.01875214  0.84861672  0.06695793  0.01516071  0.0505125 ]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['business']
# Predicted: [[ 0.72547927  0.06166045  0.05741313  0.0220063   0.13344085]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.85378251  0.01307144  0.03077474  0.08583215  0.01653916]]
# Predicted Index: ['business']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.13000109  0.76913587  0.03370554  0.03147419  0.03568332]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.0453362   0.01024597  0.92751963  0.00804547  0.00885273]]
# Predicted Index: ['politics']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.01531402  0.91927111  0.0109277   0.02814325  0.02634392]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.01425121  0.02263311  0.09740777  0.83923065  0.02647726]]
# Predicted Index: ['sport']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.36531531  0.40658341  0.00285209  0.00169183  0.22355736]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.01356139  0.01028517  0.1391418   0.01721936  0.81979228]]
# Predicted Index: ['tech']
# Correct
# Actual: ['business']
# Predicted: [[ 0.80903733  0.03487747  0.12320244  0.01869705  0.01418571]]
# Predicted Index: ['business']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.03544584  0.04660473  0.84606941  0.03520749  0.03667253]]
# Predicted Index: ['politics']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.08820145  0.01267515  0.87943519  0.00813252  0.01155569]]
# Predicted Index: ['politics']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.01908278  0.08777929  0.0181032   0.86403594  0.01099878]]
# Predicted Index: ['sport']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.05694968  0.01382747  0.0568284   0.01117787  0.86121658]]
# Predicted Index: ['tech']
# Correct
# Actual: ['business']
# Predicted: [[ 0.84417711  0.02456125  0.00503232  0.00378792  0.1224414 ]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.80993335  0.04255238  0.02464276  0.03036596  0.09250554]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.91590612  0.0168435   0.03391515  0.01412432  0.0192109 ]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.94122204  0.01912648  0.0165332   0.01215494  0.01096334]]
# Predicted Index: ['business']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.02901009  0.06595353  0.01282787  0.88088385  0.01132466]]
# Predicted Index: ['sport']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.01210643  0.02400247  0.02542185  0.91175474  0.02671451]]
# Predicted Index: ['sport']
# Correct
# Actual: ['business']
# Predicted: [[ 0.88846408  0.01665172  0.03267554  0.01868994  0.04351872]]
# Predicted Index: ['business']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.03689649  0.89807256  0.03163729  0.02118273  0.01221093]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.02985402  0.00728516  0.94905718  0.00534151  0.00846212]]
# Predicted Index: ['politics']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.07610572  0.02844659  0.829167    0.04196324  0.02431745]]
# Predicted Index: ['politics']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.01544277  0.03930505  0.03699614  0.85265377  0.05560227]]
# Predicted Index: ['sport']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.0255557   0.12034916  0.01365833  0.75951832  0.0809185 ]]
# Predicted Index: ['sport']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.02677576  0.00967519  0.04241799  0.02334636  0.89778469]]
# Predicted Index: ['tech']
# Correct
# Actual: ['business']
# Predicted: [[ 0.9101043   0.01972947  0.01010169  0.01320271  0.04686182]]
# Predicted Index: ['business']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.0532943   0.04512961  0.02554103  0.01380454  0.86223052]]
# Predicted Index: ['tech']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.05039936  0.01542608  0.07755683  0.01775416  0.83886356]]
# Predicted Index: ['tech']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.05618864  0.85911272  0.01278929  0.01410218  0.05780717]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.15767329  0.27297885  0.03383651  0.02311209  0.51239926]]
# Predicted Index: ['entertainment']
# Actual: ['business']
# Predicted: [[ 0.89332774  0.01546218  0.06407935  0.01667367  0.01045707]]
# Predicted Index: ['business']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.05185184  0.03696843  0.13061559  0.76810681  0.01245732]]
# Predicted Index: ['sport']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.00657563  0.00860613  0.91807575  0.00698432  0.05975816]]
# Predicted Index: ['politics']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.15562563  0.50217922  0.07013333  0.23034801  0.04171381]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.10443921  0.73080717  0.08242434  0.06486139  0.0174679 ]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.05294769  0.01437578  0.01631553  0.0066478   0.9097132 ]]
# Predicted Index: ['tech']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.00723238  0.0341765   0.03957789  0.07489952  0.8441137 ]]
# Predicted Index: ['tech']
# Correct
# Actual: ['business']
# Predicted: [[ 0.88205641  0.02689801  0.02757383  0.04963778  0.01383396]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.91702331  0.03364331  0.01561547  0.02077621  0.0129417 ]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.43386991  0.14201814  0.27416814  0.02235353  0.12759027]]
# Predicted Index: ['business']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.10338234  0.64941209  0.04220076  0.02663014  0.17837467]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.02758209  0.01840272  0.03216711  0.01669038  0.9051577 ]]
# Predicted Index: ['tech']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.00824647  0.07377702  0.01463661  0.89569636  0.00764354]]
# Predicted Index: ['sport']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.03906863  0.02054729  0.01688667  0.01161617  0.91188124]]
# Predicted Index: ['tech']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.01951192  0.04102155  0.7610564   0.0210189   0.15739124]]
# Predicted Index: ['politics']
# Correct
# Actual: ['business']
# Predicted: [[ 0.79833776  0.16577302  0.0051437   0.01391499  0.01683053]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.93287817  0.03589255  0.01073784  0.01016817  0.01032327]]
# Predicted Index: ['business']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.03598436  0.08554398  0.01437419  0.84853129  0.01556618]]
# Predicted Index: ['sport']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.00963488  0.01220915  0.02015283  0.07190129  0.88610185]]
# Predicted Index: ['tech']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.08856606  0.01620965  0.86564172  0.01467662  0.01490596]]
# Predicted Index: ['politics']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.48653088  0.01603262  0.33994676  0.00367138  0.15381836]]
# Predicted Index: ['politics']
# Actual: ['sport']
# Predicted: [[ 0.03481127  0.03643034  0.07282925  0.83278057  0.02314857]]
# Predicted Index: ['sport']
# Correct
# Actual: ['business']
# Predicted: [[ 0.91211878  0.02030196  0.03013925  0.02424412  0.0131959 ]]
# Predicted Index: ['business']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.0258848   0.0255563   0.02385122  0.90159992  0.02310775]]
# Predicted Index: ['sport']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.02259148  0.00858909  0.01900251  0.00901264  0.94080428]]
# Predicted Index: ['tech']
# Correct
# Actual: ['business']
# Predicted: [[ 0.92215743  0.01719291  0.01939939  0.02852454  0.01272573]]
# Predicted Index: ['business']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.01483491  0.02009901  0.04106101  0.02832289  0.89568218]]
# Predicted Index: ['tech']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.06956456  0.07175122  0.75037937  0.04364421  0.06466063]]
# Predicted Index: ['politics']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.07627895  0.67970036  0.08183137  0.00623574  0.15595357]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.02092559  0.43554747  0.2643688   0.00953032  0.26962781]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.02278385  0.02845009  0.03249928  0.90390325  0.01236353]]
# Predicted Index: ['sport']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.0189901   0.90771987  0.01624591  0.00627743  0.05076669]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['business']
# Predicted: [[ 0.94160312  0.01305575  0.01203746  0.01190151  0.02140216]]
# Predicted Index: ['business']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.05127499  0.00810551  0.90497559  0.00537592  0.03026799]]
# Predicted Index: ['politics']
# Correct
# Actual: ['entertainment']
# Predicted: [[ 0.00769116  0.93633446  0.01145201  0.03753721  0.00698516]]
# Predicted Index: ['entertainment']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.00429008  0.0215678   0.00873208  0.93892246  0.02648758]]
# Predicted Index: ['sport']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.22293075  0.1266204   0.18303024  0.40662147  0.06079713]]
# Predicted Index: ['sport']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.07019106  0.01615778  0.86137988  0.00996774  0.04230353]]
# Predicted Index: ['politics']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.09490815  0.02227562  0.0156152   0.02495483  0.84224619]]
# Predicted Index: ['tech']
# Correct
# Actual: ['politics']
# Predicted: [[ 0.01231361  0.00741876  0.9369212   0.01908811  0.02425832]]
# Predicted Index: ['politics']
# Correct
# Actual: ['tech']
# Predicted: [[ 0.01313075  0.00710426  0.01812227  0.00653014  0.95511258]]
# Predicted Index: ['tech']
# Correct
# Actual: ['business']
# Predicted: [[ 0.82273795  0.04351769  0.02146676  0.08453365  0.02774395]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.76996784  0.07286879  0.03575806  0.012045    0.10936031]]
# Predicted Index: ['business']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.02767803  0.06283238  0.02115741  0.87242271  0.01590947]]
# Predicted Index: ['sport']
# Correct
# Actual: ['business']
# Predicted: [[ 0.91010283  0.01589754  0.00859781  0.00511125  0.06029057]]
# Predicted Index: ['business']
# Correct
# Actual: ['business']
# Predicted: [[ 0.91215489  0.02509591  0.02389461  0.02190097  0.01695362]]
# Predicted Index: ['business']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.00854633  0.02574198  0.01565691  0.93305489  0.01699989]]
# Predicted Index: ['sport']
# Correct
# Actual: ['sport']
# Predicted: [[ 0.74777558  0.03561181  0.03715119  0.1535482   0.02591321]]
# Predicted Index: ['sport']

# %% [markdown]
# ### TFIDF K-NN Results:

# %%
print('Total Test Records : {}'.format(tf_X_test.shape[0]))
print('Total Correct Predictions : {}'.format(correct_predictions))
print('Total Wrong Predictions : {}'.format(wrong_predictions))
tf_knn_rate = (correct_predictions/tf_X_test.shape[0])* 100
print('Success Rate : {}%'.format(tf_knn_rate))
# Out:
# Total Test Records : 125
# Total Correct Predictions : 122
# Total Wrong Predictions : 3
# Success Rate : 97.6%

# %% [markdown]
# ## DFICF K-NN Processing

# %%
clf.fit(df_X_train, df_y_train_encoded)
# Out:
# CalibratedClassifierCV(base_estimator=LinearSVC(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#             cv=5, method='sigmoid')

# %%
#KNN Labels
clf.classes_
# Out:
# array([0, 1, 2, 3, 4])

# %%
#KNN Encoded Labels
df_y_unique_labels
# Out:
# array(['business', 'entertainment', 'politics', 'sport', 'tech'],
#       dtype='<U13')

# %%
correct_predictions = 0
wrong_predictions = 0
window_size = df_y_unique_labels.shape[0]
# iteration should be achieved in every jump_step/block like window_size, 
# because, df_X_test is ordered by the document index, or in other terms same document
# same document is getting repearted in each window
# thus, in each window, we need to iterate again for each document in this window.
for step in range(0, df_X_test.shape[0], window_size):
    max_predicted = None
    max_predicted_value = 0
    print(10 * '*')
    for indx in range(step, step + window_size):
        print('step:', step)
        print('index:', indx)
        print('record:', df_X_test[indx])
        print('label:', df_potential_category_test[indx])
        df_X_sample_record = df_X_test[indx].reshape(1, df_X_test[indx].shape[0])
        #sample_indx = 0
        #tf_X_sample = tf_X_test[sample_indx].reshape(1, tf_X_test[sample_indx].shape[0])
        predicted = clf.predict_proba(df_X_sample_record)
        predicted_value = np.max(predicted)
        print('Predictions in Window:', predicted)
        if predicted_value > max_predicted_value:
            max_predicted_value = predicted_value
            max_predicted = predicted
    
#     print('Max predicted:', max_predicted)
#     print('Max predicted value:', max_predicted_value)
    max_predicted_index = np.argmax(max_predicted)
#     print('Max predicted index:', max_predicted_index)
    
#     print('Predicted:', tf_y_unique_labels[max_predicted_index])
#     print('Actual:', df_y_test[step])
    if (df_y_unique_labels[max_predicted_index] == df_y_test[step]):
        correct_predictions +=1
    else:
        wrong_predictions +=1
        print('Max predicted:', max_predicted)
        print('Max predicted value:', max_predicted_value)
        print('Max predicted index:', max_predicted_index)
        print('Predicted:', tf_y_unique_labels[max_predicted_index])
        print('Actual:', df_y_test[step])
        print('Wrong','!'* 10)
# Out:
# **********
# step: 0
# index: 0
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.33433687  0.16111071  0.19803807  0.19278818  0.11372617]]
# step: 30
# index: 34
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.4679099   0.1474427   0.13488097  0.15501179  0.09475464]]
# **********
# step: 35
# index: 35
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.84161191  0.04492377  0.04205256  0.03468198  0.03672978]]
# step: 35
# index: 36
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.50790421  0.16970908  0.11382871  0.12045504  0.08810295]]
# step: 35
# index: 37
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.49602751  0.15177446  0.11633879  0.15001284  0.0858464 ]]
# step: 35
# index: 38
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.62846213  0.11300983  0.08708865  0.0893994   0.08204   ]]
# step: 35
# index: 39
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.45878477  0.13691797  0.2112568   0.1141842   0.07885625]]
# **********
# step: 40
# index: 40
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.45913193  0.18293793  0.13512086  0.12461687  0.0981924 ]]
# step: 40
# index: 41
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.44242026  0.17112756  0.14343708  0.14719544  0.09581967]]
# step: 40
# index: 42
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.0372291   0.04698299  0.06149239  0.03575205  0.81854346]]
# step: 40
# index: 43
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.39907621  0.15483014  0.21030913  0.11956578  0.11621875]]
# step: 40
# index: 44
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.5661609   0.12817606  0.12079818  0.09436959  0.09049527]]
# **********
# step: 45
# index: 45
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.33887558  0.22730858  0.16588006  0.10508414  0.16285164]]
# step: 45
# index: 46
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.17559361  0.56906819  0.1002551   0.07883207  0.07625104]]
# step: 45
# index: 47
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.5531338   0.13792216  0.12251142  0.09935144  0.08708119]]
# step: 45
# index: 48
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.43529255  0.15259079  0.19073974  0.11340434  0.10797259]]
# step: 45
# index: 49
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.44046848  0.16685951  0.14033408  0.15675347  0.09558447]]
# **********
# step: 50
# index: 50
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.10837461  0.08302876  0.07980881  0.65353664  0.07525119]]
# step: 50
# index: 51
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.29570731  0.14856896  0.15133061  0.25630387  0.14808925]]
# step: 50
# index: 52
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.40564186  0.18569733  0.14313604  0.16016869  0.10535609]]
# step: 50
# index: 53
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.41063673  0.16804052  0.16013814  0.1455054   0.11567921]]
# step: 50
# index: 54
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.48050133  0.14938629  0.13001102  0.14270117  0.09740019]]
# **********
# step: 55
# index: 55
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.48728944  0.17197782  0.11813744  0.12993625  0.09265905]]
# step: 55
# index: 56
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.61616724  0.11428939  0.08992054  0.07437591  0.10524692]]
# step: 55
# index: 57
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.74914337  0.07748888  0.06437993  0.05010296  0.05888486]]
# step: 55
# index: 58
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.49556359  0.17758034  0.11607795  0.1169572   0.09382092]]
# step: 55
# index: 59
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.54735407  0.14428257  0.11991514  0.10144564  0.08700257]]
# **********
# step: 60
# index: 60
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.42191752  0.16459112  0.15494208  0.16764769  0.09090159]]
# step: 60
# index: 61
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.5727477   0.12971937  0.11210742  0.11265834  0.07276717]]
# step: 60
# index: 62
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.0362376   0.05221455  0.05985995  0.81347192  0.03821598]]
# step: 60
# index: 63
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.41428341  0.18183344  0.1423801   0.16837841  0.09312464]]
# step: 60
# index: 64
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.41750272  0.16820458  0.14437468  0.1731427   0.09677532]]
# **********
# step: 65
# index: 65
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.16475835  0.11350136  0.11501895  0.48441476  0.12230657]]
# step: 65
# index: 66
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.17228055  0.40300148  0.1184295   0.10746851  0.19881996]]
# step: 65
# index: 67
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.65836646  0.08215944  0.0908339   0.0798106   0.0888296 ]]
# step: 65
# index: 68
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.00656816  0.02894103  0.03911731  0.03105858  0.89431492]]
# step: 65
# index: 69
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.3708572   0.13933095  0.22525114  0.12361996  0.14094075]]
# **********
# step: 70
# index: 70
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.02481671  0.03602095  0.04580174  0.85392213  0.03943847]]
# step: 70
# index: 71
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.516673    0.14763382  0.11423034  0.13712925  0.08433359]]
# step: 70
# index: 72
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.42289411  0.20750176  0.1302873   0.14766628  0.09165056]]
# step: 70
# index: 73
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.3089564   0.14399045  0.12047572  0.31669655  0.10988088]]
# step: 70
# index: 74
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.24434182  0.15037741  0.3329693   0.17818648  0.09412498]]
# **********
# step: 75
# index: 75
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.63487572  0.0972092   0.08443796  0.07845815  0.10501898]]
# step: 75
# index: 76
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.52127464  0.14202486  0.12865899  0.1213773   0.08666421]]
# step: 75
# index: 77
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.81621818  0.05212045  0.048509    0.03863074  0.04452163]]
# step: 75
# index: 78
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.4299541   0.16923332  0.13023256  0.17774008  0.09283994]]
# step: 75
# index: 79
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.47633374  0.18056695  0.12090493  0.13232123  0.08987315]]
# **********
# step: 80
# index: 80
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.62351664  0.12856907  0.08931402  0.08542665  0.07317362]]
# step: 80
# index: 81
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.53981733  0.15952351  0.10502406  0.10285498  0.09278012]]
# step: 80
# index: 82
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.19663838  0.58659189  0.08019217  0.07058965  0.06598791]]
# step: 80
# index: 83
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.50370277  0.16774119  0.12207298  0.11886222  0.08762084]]
# step: 80
# index: 84
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.44783353  0.17879821  0.114768    0.17193822  0.08666203]]
# Max predicted: [[ 0.62351664  0.12856907  0.08931402  0.08542665  0.07317362]]
# Max predicted value: 0.623516636634
# Max predicted index: 0
# Predicted: business
# Actual: ['entertainment']
# Wrong !!!!!!!!!!
# **********
# step: 85
# index: 85
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.50279497  0.15657603  0.13892808  0.11567443  0.08602648]]
# step: 85
# index: 86
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.64770709  0.12079342  0.08892201  0.07656227  0.06601521]]
# step: 85
# index: 87
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.27109766  0.29866323  0.10800598  0.09048327  0.23174986]]
# step: 85
# index: 88
# record: [ 0.          0.25216053  0.         ...,  0.50432107  0.          0.        ]
# label: ['entertainment']
# Predictions in Window: [[ 0.03579643  0.85641292  0.04428313  0.02881286  0.03469466]]
# step: 85
# index: 89
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.4218051   0.17828324  0.12394477  0.18148128  0.09448561]]
# **********
# step: 90
# index: 90
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.84644786  0.04326271  0.04234141  0.03041522  0.03753279]]
# step: 90
# index: 91
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.61203701  0.13662832  0.08789641  0.07629426  0.087144  ]]
# step: 90
# index: 92
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.42995144  0.23898094  0.12054357  0.11360049  0.09692357]]
# step: 90
# index: 93
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.45716303  0.17221278  0.13091031  0.14390706  0.09580683]]
# step: 90
# index: 94
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.53786174  0.14401103  0.12516202  0.1091244   0.08384082]]
# **********
# step: 95
# index: 95
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[  1.69384450e-04   9.07979673e-03   9.67255960e-01   5.49750013e-03
#     1.79973589e-02]]
# step: 95
# index: 96
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.69713754  0.07372789  0.10865008  0.05985868  0.06062581]]
# step: 95
# index: 97
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.44485819  0.13215828  0.17838193  0.10339061  0.14121099]]
# step: 95
# index: 98
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.4339308   0.1830687   0.14945309  0.12662899  0.10691842]]
# step: 95
# index: 99
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.45517103  0.15323594  0.14356381  0.14435958  0.10366964]]
# **********
# step: 100
# index: 100
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.42880578  0.19373329  0.1369511   0.13243086  0.10807896]]
# step: 100
# index: 101
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.21321645  0.32082442  0.11922556  0.10149715  0.24523642]]
# step: 100
# index: 102
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.36600829  0.1946368   0.19696319  0.13713565  0.10525607]]
# step: 100
# index: 103
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.40876397  0.19660274  0.13615952  0.15234991  0.10612385]]
# step: 100
# index: 104
# record: [ 0.          0.25216053  0.         ...,  0.          0.          0.        ]
# label: ['entertainment']
# Predictions in Window: [[ 0.02973104  0.83684071  0.05136802  0.03200538  0.05005484]]
# **********
# step: 105
# index: 105
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.50806443  0.15743379  0.13456524  0.08956084  0.1103757 ]]
# step: 105
# index: 106
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.11432612  0.11786164  0.10219232  0.04651882  0.6191011 ]]
# step: 105
# index: 107
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.29122623  0.14947676  0.36445186  0.08461796  0.11022719]]
# step: 105
# index: 108
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.25244505  0.42210126  0.11631585  0.0796055   0.12953234]]
# step: 105
# index: 109
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.41812551  0.18184798  0.14704431  0.14921822  0.10376399]]
# Max predicted: [[ 0.11432612  0.11786164  0.10219232  0.04651882  0.6191011 ]]
# Max predicted value: 0.619101099812
# Max predicted index: 4
# Predicted: tech
# Actual: ['entertainment']
# Wrong !!!!!!!!!!
# **********
# step: 110
# index: 110
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.67934872  0.09222789  0.08517831  0.05583786  0.08740723]]
# step: 110
# index: 111
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.45369304  0.13097583  0.16422905  0.08520675  0.16589533]]
# step: 110
# index: 112
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.43435989  0.19967269  0.12723226  0.1023239   0.13641125]]
# step: 110
# index: 113
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.45723002  0.17003249  0.13363081  0.12966171  0.10944498]]
# step: 110
# index: 114
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.00898477  0.02760299  0.0362636   0.01340624  0.9137424 ]]
# **********
# step: 115
# index: 115
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.48661102  0.14444285  0.15293544  0.12517619  0.0908345 ]]
# step: 115
# index: 116
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.01173182  0.04375972  0.86980116  0.03449154  0.04021576]]
# step: 115
# index: 117
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.3591943   0.15590583  0.20653196  0.15164436  0.12672355]]
# step: 115
# index: 118
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.40499528  0.18020383  0.15335439  0.16096022  0.10048629]]
# step: 115
# index: 119
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.36673302  0.17061627  0.15442242  0.20793718  0.10029111]]
# **********
# step: 120
# index: 120
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.46346378  0.16702825  0.14477865  0.13252787  0.09220145]]
# step: 120
# index: 121
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.28353271  0.36033383  0.11065437  0.09678119  0.14869791]]
# step: 120
# index: 122
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.08465595  0.70817401  0.06690557  0.05076083  0.08950365]]
# step: 120
# index: 123
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.44770624  0.1825172   0.12571069  0.15245914  0.09160673]]
# step: 120
# index: 124
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.51289151  0.17105411  0.11551589  0.11523242  0.08530606]]
# **********
# step: 125
# index: 125
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.38420998  0.14894267  0.162879    0.20851512  0.09545322]]
# step: 125
# index: 126
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.24132346  0.11853108  0.12089916  0.40327874  0.11596757]]
# step: 125
# index: 127
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.52134937  0.13230058  0.11513112  0.14719531  0.08402362]]
# step: 125
# index: 128
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.00622456  0.02285482  0.03617509  0.90643032  0.0283152 ]]
# step: 125
# index: 129
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.41245856  0.17935356  0.1309319   0.18178091  0.09547508]]
# **********
# step: 130
# index: 130
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.59757389  0.11640222  0.11929982  0.08859783  0.07812624]]
# step: 130
# index: 131
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.51177074  0.13584354  0.14249605  0.10408778  0.10580188]]
# step: 130
# index: 132
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.01902478  0.04646929  0.86276717  0.03460134  0.03713742]]
# step: 130
# index: 133
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.461795    0.18317377  0.13859455  0.12472524  0.09171144]]
# step: 130
# index: 134
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.45069737  0.16039653  0.14147687  0.15742428  0.09000495]]
# **********
# step: 135
# index: 135
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.52986888  0.16298809  0.10552661  0.11414835  0.08746807]]
# step: 135
# index: 136
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.32483999  0.18864318  0.11884914  0.27062343  0.09704425]]
# step: 135
# index: 137
# record: [ 0.          0.          0.         ...,  0.50432107  0.          0.        ]
# label: ['entertainment']
# Predictions in Window: [[ 0.00636446  0.92588438  0.03090899  0.01749797  0.0193442 ]]
# step: 135
# index: 138
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.39189861  0.20469652  0.15866355  0.14397328  0.10076804]]
# step: 135
# index: 139
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.34799758  0.31460259  0.10808854  0.11866191  0.11064938]]
# **********
# step: 140
# index: 140
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.06799375  0.07735225  0.07434092  0.73135246  0.04896063]]
# step: 140
# index: 141
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.31224382  0.17646     0.17152867  0.19273823  0.14702928]]
# step: 140
# index: 142
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.36986777  0.16355369  0.17397172  0.16925121  0.12335561]]
# step: 140
# index: 143
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.3818198   0.20222414  0.13654702  0.17083872  0.10857032]]
# step: 140
# index: 144
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.48820996  0.15956179  0.12793381  0.12942179  0.09487264]]
# **********
# step: 145
# index: 145
# record: [ 0.          0.          0.         ...,  0.          0.00772259  0.        ]
# label: ['tech']
# Predictions in Window: [[ 0.25035238  0.1285247   0.13548489  0.36446336  0.12117467]]
# step: 145
# index: 146
# record: [ 0.          0.          0.         ...,  0.          0.00736785  0.        ]
# label: ['politics']
# Predictions in Window: [[ 0.40245398  0.15440784  0.17779329  0.16788916  0.09745573]]
# step: 145
# index: 147
# record: [ 0.          0.          0.         ...,  0.          0.01492945  0.        ]
# label: ['sport']
# Predictions in Window: [[ 0.01971642  0.03286455  0.04754292  0.85078659  0.04908952]]
# step: 145
# index: 148
# record: [ 0.          0.          0.         ...,  0.          0.00811091  0.        ]
# label: ['entertainment']
# Predictions in Window: [[ 0.4052847   0.18207441  0.14775448  0.16413713  0.10074928]]
# step: 145
# index: 149
# record: [ 0.          0.          0.         ...,  0.          0.00895767  0.        ]
# label: ['business']
# Predictions in Window: [[ 0.46462589  0.14523738  0.13704044  0.16054084  0.09255546]]
# **********
# step: 150
# index: 150
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.47568377  0.17339365  0.13642899  0.12501965  0.08947395]]
# step: 150
# index: 151
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.43951494  0.18411564  0.12168511  0.16127799  0.09340632]]
# step: 150
# index: 152
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.63369715  0.12986062  0.0875621   0.08177516  0.06710496]]
# step: 150
# index: 153
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.37460657  0.19076632  0.10444687  0.09720375  0.2329765 ]]
# step: 150
# index: 154
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.23281971  0.51188204  0.08809343  0.08240818  0.08479665]]
# Max predicted: [[ 0.63369715  0.12986062  0.0875621   0.08177516  0.06710496]]
# Max predicted value: 0.633697152455
# Max predicted index: 0
# Predicted: business
# Actual: ['entertainment']
# Wrong !!!!!!!!!!
# **********
# step: 155
# index: 155
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.43068997  0.17113681  0.1384354   0.14745826  0.11227955]]
# step: 185
# index: 189
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.05024798  0.05710721  0.05288099  0.80230015  0.03746367]]
# **********
# step: 190
# index: 190
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.50536087  0.11404778  0.09563145  0.0802405   0.2047194 ]]
# step: 190
# index: 191
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.47631891  0.16059845  0.124491    0.14473368  0.09385797]]
# step: 190
# index: 192
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.50498898  0.17850118  0.11477767  0.1052679   0.09646427]]
# step: 190
# index: 193
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.80126786  0.0581773   0.05399436  0.0384473   0.04811318]]
# step: 190
# index: 194
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.51210271  0.15214614  0.13314948  0.11188963  0.09071204]]
# **********
# step: 195
# index: 195
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.50909522  0.14945727  0.11675287  0.14439111  0.08030354]]
# step: 195
# index: 196
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.51168449  0.17135154  0.113872    0.12069446  0.08239752]]
# step: 195
# index: 197
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.65483917  0.09967026  0.0895206   0.08175353  0.07421645]]
# step: 195
# index: 198
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.83576514  0.04323282  0.04674666  0.036572    0.03768338]]
# step: 195
# index: 199
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.57360696  0.11998422  0.12988483  0.10463628  0.07188771]]
# **********
# step: 200
# index: 200
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.43885268  0.16099515  0.13479979  0.17501162  0.09034077]]
# step: 200
# index: 201
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.54086705  0.12536003  0.13760361  0.10520529  0.09096403]]
# step: 200
# index: 202
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.4678298   0.17509763  0.13442253  0.12417032  0.09847971]]
# step: 200
# index: 203
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.77499874  0.06278208  0.06548022  0.04958908  0.04714987]]
# step: 200
# index: 204
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.50422928  0.14208251  0.1381303   0.10472719  0.11083073]]
# **********
# step: 205
# index: 205
# record: [ 0.          0.          0.         ...,  0.          0.00895767  0.        ]
# label: ['business']
# Predictions in Window: [[ 0.59247835  0.11658122  0.11048364  0.0979654   0.08249138]]
# step: 205
# index: 206
# record: [ 0.          0.          0.         ...,  0.          0.01492945  0.        ]
# label: ['sport']
# Predictions in Window: [[ 0.01819287  0.03667351  0.04445099  0.86609407  0.03458855]]
# step: 205
# index: 207
# record: [ 0.          0.          0.         ...,  0.          0.00811091  0.        ]
# label: ['entertainment']
# Predictions in Window: [[ 0.44856634  0.17418142  0.13277118  0.14673285  0.09774822]]
# step: 205
# index: 208
# record: [ 0.          0.          0.         ...,  0.          0.00772259  0.        ]
# label: ['tech']
# Predictions in Window: [[ 0.48121784  0.13092308  0.12125035  0.12012903  0.1464797 ]]
# step: 205
# index: 209
# record: [ 0.          0.          0.         ...,  0.          0.00736785  0.        ]
# label: ['politics']
# Predictions in Window: [[ 0.47913907  0.14239356  0.15323394  0.13078125  0.09445218]]
# **********
# step: 210
# index: 210
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.70468145  0.09238915  0.07539383  0.06210237  0.0654332 ]]
# step: 210
# index: 211
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.49122622  0.15632932  0.13672343  0.11997403  0.095747  ]]
# step: 210
# index: 212
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.49115623  0.15560206  0.12288493  0.13570993  0.09464684]]
# step: 210
# index: 213
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.46329126  0.22126927  0.11824781  0.10385543  0.09333622]]
# step: 210
# index: 214
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.54849129  0.1250999   0.10758669  0.08464107  0.13418106]]
# **********
# step: 215
# index: 215
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.8783788   0.02981864  0.03851795  0.02283776  0.03044685]]
# step: 215
# index: 216
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.51567279  0.16964013  0.11444721  0.11252454  0.08771533]]
# step: 215
# index: 217
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.51803748  0.15495548  0.11762398  0.11579846  0.0935846 ]]
# step: 245
# index: 249
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.2294645   0.30218199  0.13465599  0.1094682   0.22422932]]
# **********
# step: 250
# index: 250
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.47169152  0.16163097  0.1249115   0.14176514  0.10000087]]
# step: 250
# index: 251
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.02544338  0.02586408  0.03900123  0.02031021  0.88938111]]
# step: 250
# index: 252
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.47855521  0.17293109  0.11974809  0.11545821  0.1133074 ]]
# step: 250
# index: 253
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.67164851  0.08967289  0.08978955  0.0632952   0.08559386]]
# step: 250
# index: 254
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.49464333  0.12444645  0.16336867  0.08994345  0.1275981 ]]
# **********
# step: 255
# index: 255
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.47091236  0.15938957  0.11813558  0.15549628  0.09606622]]
# step: 255
# index: 256
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.16952048  0.104802    0.08449158  0.58211722  0.05906872]]
# step: 255
# index: 257
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.44715     0.19054074  0.11676307  0.15662389  0.08892231]]
# step: 255
# index: 258
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.48009767  0.15684126  0.12657307  0.14815662  0.08833138]]
# step: 255
# index: 259
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.51797684  0.1535987   0.11285957  0.13045224  0.08511266]]
# **********
# step: 260
# index: 260
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.41636905  0.15904998  0.14833754  0.1688404   0.10740303]]
# step: 260
# index: 261
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.3448603   0.14102792  0.22683996  0.11559028  0.17168154]]
# step: 260
# index: 262
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.01751035  0.03602591  0.87495173  0.02703219  0.04447981]]
# step: 260
# index: 263
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.53363867  0.13234843  0.14307024  0.09983422  0.09110844]]
# step: 260
# index: 264
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.4582805   0.16970319  0.14935952  0.11800294  0.10465385]]
# **********
# step: 265
# index: 265
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.32619559  0.27280274  0.11201881  0.10532126  0.1836616 ]]
# step: 265
# index: 266
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.2344178   0.4794075   0.09618517  0.09154384  0.0984457 ]]
# step: 265
# index: 267
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.45324465  0.17324032  0.12605918  0.15430338  0.09315246]]
# step: 265
# index: 268
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.61665182  0.12794221  0.09309701  0.090865    0.07144396]]
# step: 265
# index: 269
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.49399887  0.15556698  0.13396372  0.12439978  0.09207066]]
# Max predicted: [[ 0.61665182  0.12794221  0.09309701  0.090865    0.07144396]]
# Max predicted value: 0.616651820465
# Max predicted index: 0
# Predicted: business
# Actual: ['entertainment']
# Wrong !!!!!!!!!!
# **********
# step: 270
# index: 270
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.32238891  0.13614244  0.07687237  0.05635158  0.4082447 ]]
# step: 270
# index: 271
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.47353766  0.16520136  0.11856951  0.1550327   0.08765877]]
# step: 270
# index: 272
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.5658574   0.13163952  0.12162462  0.09908225  0.08179621]]
# step: 270
# index: 273
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.73511541  0.08369781  0.0692168   0.05185471  0.06011527]]
# step: 270
# index: 274
# ...
# **********
# step: 535
# index: 535
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.3381088   0.15161761  0.16069957  0.22994473  0.1196293 ]]
# step: 535
# index: 536
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.35061644  0.12777436  0.24714229  0.13274543  0.14172148]]
# step: 535
# index: 537
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.32918429  0.24038008  0.15681335  0.14678612  0.12683616]]
# step: 535
# index: 538
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.55408553  0.10785061  0.13084708  0.10616048  0.10105631]]
# step: 535
# index: 539
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.00528034  0.02018764  0.04791271  0.03426438  0.89235492]]
# **********
# step: 540
# index: 540
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.42851044  0.15561771  0.17196532  0.137506    0.10640053]]
# step: 540
# index: 541
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.44707234  0.18130132  0.14328994  0.1353161   0.09302029]]
# step: 540
# index: 542
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.49556312  0.14282109  0.1655027   0.11222678  0.08388631]]
# step: 540
# index: 543
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.16607248  0.09797454  0.5865397   0.07661073  0.07280255]]
# step: 540
# index: 544
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.41936902  0.16838319  0.14670453  0.16638357  0.09915969]]
# **********
# step: 545
# index: 545
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.57880456  0.13689801  0.10444175  0.10435985  0.07549584]]
# step: 545
# index: 546
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.49661839  0.17174674  0.11463793  0.1319992   0.08499775]]
# step: 545
# index: 547
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.81999017  0.05450048  0.04859521  0.03954401  0.03737013]]
# step: 545
# index: 548
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.5032369   0.17750768  0.11178225  0.12186132  0.08561184]]
# step: 545
# index: 549
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.59211822  0.13559433  0.09649792  0.09664065  0.07914887]]
# **********
# step: 550
# index: 550
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.19607674  0.12448834  0.1380338   0.39545132  0.1459498 ]]
# step: 550
# index: 551
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.47427036  0.14409872  0.12242277  0.16648566  0.09272249]]
# step: 550
# index: 552
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.01428349  0.0302713   0.041978    0.87609734  0.03736987]]
# step: 550
# index: 553
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.3697994   0.18865089  0.14141079  0.19711444  0.10302447]]
# step: 550
# index: 554
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.3205949   0.16125271  0.19237329  0.2095046   0.1162745 ]]
# **********
# step: 555
# index: 555
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.00129525  0.01569609  0.95111463  0.01035969  0.02153433]]
# step: 555
# index: 556
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.46018149  0.13744061  0.19010349  0.09644535  0.11582906]]
# step: 555
# index: 557
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.46942271  0.16074227  0.13940771  0.13637429  0.09405302]]
# step: 555
# index: 558
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.48580565  0.17384252  0.13366959  0.11395027  0.09273196]]
# step: 555
# index: 559
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.77915499  0.05968884  0.07742473  0.04111403  0.0426174 ]]
# **********
# step: 560
# index: 560
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.43575669  0.14841104  0.13505658  0.18173069  0.099045  ]]
# step: 560
# index: 561
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.55431964  0.10498185  0.15661219  0.09417677  0.08990956]]
# step: 560
# index: 562
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.53527397  0.11226181  0.13296544  0.09895853  0.12054025]]
# step: 560
# index: 563
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.47309888  0.17798944  0.12944906  0.12308305  0.09637957]]
# step: 560
# index: 564
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.87078958  0.02991076  0.04260228  0.0246818   0.03201558]]
# **********
# step: 565
# index: 565
# record: [ 0.          0.          0.         ...,  0.          0.00811091  0.        ]
# label: ['entertainment']
# Predictions in Window: [[ 0.49576488  0.16475075  0.12905893  0.11774252  0.09268291]]
# step: 565
# index: 566
# record: [ 0.          0.          0.         ...,  0.          0.00895767  0.        ]
# label: ['business']
# Predictions in Window: [[ 0.78351793  0.062414    0.06087676  0.04333254  0.04985876]]
# step: 565
# index: 567
# record: [ 0.          0.          0.         ...,  0.          0.01492945  0.        ]
# label: ['sport']
# Predictions in Window: [[ 0.47516775  0.15863072  0.13488457  0.13693804  0.09437892]]
# step: 565
# index: 568
# record: [ 0.          0.          0.         ...,  0.          0.00772259  0.        ]
# label: ['tech']
# Predictions in Window: [[ 0.61606401  0.10776981  0.09972436  0.08175563  0.09468619]]
# step: 565
# index: 569
# record: [ 0.          0.          0.         ...,  0.          0.00736785  0.        ]
# label: ['politics']
# Predictions in Window: [[ 0.54193539  0.13501784  0.13357771  0.10654856  0.0829205 ]]
# **********
# step: 570
# index: 570
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.05128963  0.0281632   0.03570542  0.03043149  0.85441027]]
# step: 600
# index: 604
# record: [ 0.02444963  0.          0.         ...,  0.          0.          0.        ]
# label: ['business']
# Predictions in Window: [[ 0.75841449  0.0659868   0.06494374  0.04430338  0.06635159]]
# **********
# step: 605
# index: 605
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.35969737  0.21526099  0.14706639  0.16838892  0.10958632]]
# step: 605
# index: 606
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.35620407  0.15589321  0.17744357  0.16642068  0.14403847]]
# step: 605
# index: 607
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.3289205   0.14850479  0.1403961   0.27415645  0.10802215]]
# step: 605
# index: 608
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.11398877  0.0707996   0.09624035  0.08700124  0.63197004]]
# step: 605
# index: 609
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.53211685  0.12490324  0.12127082  0.12513546  0.09657363]]
# **********
# step: 610
# index: 610
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.37114953  0.17630799  0.16856323  0.1713658   0.11261345]]
# step: 610
# index: 611
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.65289327  0.08546964  0.12410798  0.06373228  0.07379683]]
# step: 610
# index: 612
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.40329725  0.18963631  0.16432297  0.1329773   0.10976616]]
# step: 610
# index: 613
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[  1.27400922e-04   7.11216135e-03   9.71774275e-01   4.70752571e-03
#     1.62786366e-02]]
# step: 610
# index: 614
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.33443527  0.12104024  0.2333241   0.08959031  0.22161007]]
# **********
# step: 615
# index: 615
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.56207185  0.12437263  0.11294188  0.09544957  0.10516407]]
# step: 615
# index: 616
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.38506463  0.16079065  0.1395129   0.19261301  0.12201881]]
# step: 615
# index: 617
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.44297658  0.17845792  0.13397858  0.12972474  0.11486218]]
# step: 615
# index: 618
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.4187756   0.14244446  0.16936408  0.12017707  0.14923878]]
# step: 615
# index: 619
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.03704154  0.0311353   0.05214638  0.04417735  0.83549944]]
# **********
# step: 620
# index: 620
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['politics']
# Predictions in Window: [[ 0.46762843  0.15785944  0.14135245  0.13936724  0.09379244]]
# step: 620
# index: 621
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['entertainment']
# Predictions in Window: [[ 0.45634666  0.18637649  0.13555642  0.12485673  0.09686369]]
# step: 620
# index: 622
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['business']
# Predictions in Window: [[ 0.5038853   0.15405509  0.13005297  0.12132028  0.09068636]]
# step: 620
# index: 623
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['tech']
# Predictions in Window: [[ 0.45512969  0.16584601  0.13811666  0.12446175  0.11644589]]
# step: 620
# index: 624
# record: [ 0.  0.  0. ...,  0.  0.  0.]
# label: ['sport']
# Predictions in Window: [[ 0.34813867  0.14516465  0.13011564  0.29491764  0.08166341]]
# Max predicted: [[ 0.5038853   0.15405509  0.13005297  0.12132028  0.09068636]]
# Max predicted value: 0.503885301376
# Max predicted index: 0
# Predicted: business
# Actual: ['sport']
# Wrong !!!!!!!!!!

# %% [markdown]
# ### DFICF K-NN Results:

# %%
print('Total Test Records : {}'.format(df_X_test.shape[0]/window_size))
print('Total Correct Predictions : {}'.format(correct_predictions))
print('Total Wrong Predictions : {}'.format(wrong_predictions))
df_knn_rate = (correct_predictions/(df_X_test.shape[0]/window_size))* 100
print('Success Rate : {}%'.format(df_knn_rate))
# Out:
# Total Test Records : 125.0
# Total Correct Predictions : 109
# Total Wrong Predictions : 16
# Success Rate : 87.2%
